# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
sns.set_theme()

np.random.seed(0)

path = '../data/filtered_data/'

electrodes = np.load(path + 'electrodes.npy')
signals = np.load(path + 'signals.npy')
targets = np.load(path + 'targets.npy')

# %%
idx = np.random.randint(signals.shape[0])
no_channels = 64

fig, ax = plt.subplots(no_channels, 1, figsize=(16,60), sharex=True)
fig.suptitle('Signals for ' + targets[idx], fontsize=20)
for i in range(no_channels):
    ax = plt.subplot(no_channels,1, i+1)
    ax.plot(signals[idx,i,:])
    ax.set_ylabel(electrodes[i])

fig.tight_layout()
fig.subplots_adjust(top=0.97)
plt.show()

# %%
electrodes
# Out:
# array(['Fc5', 'Fc3', 'Fc1', 'Fcz', 'Fc2', 'Fc4', 'Fc6', 'C5', 'C3', 'C1',
#        'Cz', 'C2', 'C4', 'C6', 'Cp5', 'Cp3', 'Cp1', 'Cpz', 'Cp2', 'Cp4',
#        'Cp6', 'Fp1', 'Fpz', 'Fp2', 'Af7', 'Af3', 'Afz', 'Af4', 'Af8',
#        'F7', 'F5', 'F3', 'F1', 'Fz', 'F2', 'F4', 'F6', 'F8', 'Ft7', 'Ft8',
#        'T7', 'T8', 'T9', 'T10', 'Tp7', 'Tp8', 'P7', 'P5', 'P3', 'P1',
#        'Pz', 'P2', 'P4', 'P6', 'P8', 'Po7', 'Po3', 'Poz', 'Po4', 'Po8',
#        'O1', 'Oz', 'O2', 'Iz'], dtype='<U3')

# %%
[el.replace('.','') for el in electrodes]
# Out:
# ['Fc5',
#  'Fc3',
#  'Fc1',
#  'Fcz',
#  'Fc2',
#  'Fc4',
#  'Fc6',
#  'C5',
#  'C3',
#  'C1',
#  'Cz',
#  'C2',
#  'C4',
#  'C6',
#  'Cp5',
#  'Cp3',
#  'Cp1',
#  'Cpz',
#  'Cp2',
#  'Cp4',
#  'Cp6',
#  'Fp1',
#  'Fpz',
#  'Fp2',
#  'Af7',
#  'Af3',
#  'Afz',
#  'Af4',
#  'Af8',
#  'F7',
#  'F5',
#  'F3',
#  'F1',
#  'Fz',
#  'F2',
#  'F4',
#  'F6',
#  'F8',
#  'Ft7',
#  'Ft8',
#  'T7',
#  'T8',
#  'T9',
#  'T10',
#  'Tp7',
#  'Tp8',
#  'P7',
#  'P5',
#  'P3',
#  'P1',
#  'Pz',
#  'P2',
#  'P4',
#  'P6',
#  'P8',
#  'Po7',
#  'Po3',
#  'Poz',
#  'Po4',
#  'Po8',
#  'O1',
#  'Oz',
#  'O2',
#  'Iz']
